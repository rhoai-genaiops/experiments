# %% [markdown]
# # 🔢 Understanding Text Embeddings
#
# Welcome to the world of embeddings! Before we dive into RAG, let's understand the fundamental concept that makes it all possible: **text embeddings** 🪄.
#
# Think of embeddings as a way to teach computers the *meaning* of text by converting words, sentences, or even full sections into numbers. This simple concept revolutionizes how AI systems understand and search through text.
#
# Let's explore how this magic works! ✨

# %% [markdown]
# ## 📚 Import Libraries
#
# Import the tools we'll use to create embeddings and measure similarity.

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

print("🧠 Ready to explore embeddings!")

# %% [markdown]
# ## 🔢 From Words to Numbers: A Simple Example
#
# Here's how different words become different vectors (simplified to just 4 dimensions for illustration):
#
# - `"dog"` → [0.2, 0.8, 0.1, 0.6]
# - `"puppy"` → [0.3, 0.7, 0.2, 0.5] (similar to dog - both canines)
# - `"cat"` → [0.1, 0.6, 0.8, 0.3] (different but some similarity - still a pet)
# - `"car"` → [0.9, 0.1, 0.2, 0.1] (completely different - not an animal)
#
# In real embeddings, these vectors have hundreds or thousands of dimensions, capturing subtle meaning and semantics!

# %% [markdown]
# ## 🧪 Let's Create Real Embeddings!
#
# Now let's see this in action! We'll convert those same words into actual embedding vectors.
# To do this, we will use an **embedding model**. An embedding model is an LLM where we grab the "internal representation of the inputted words and sentences" from the LLM. These outputs (embeddings) are typically represented as vectors and have a semantic meaning as they come from within a learned LLM.

# %%
# Load a pre-trained embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Our example words from the diagram
words = ["dog", "puppy", "cat", "car"]

# Convert words to embeddings (vectors)
embeddings = model.encode(words)

print("🔢 Converting words to vectors:")
for word, embedding in zip(words, embeddings):
    print(f"'{word}' → vector with {len(embedding)} dimensions")
    print(f"   First 5 values: {embedding[:5]}")
    print()

# %% [markdown]
# ## ✨ The Vector Magic
#
# 1. **Text → Numbers**: Every piece of text gets converted into a list of numbers (a vector) that captures its meaning
# 2. **Similarity Matching**: When you ask a question, the system finds vectors that are close in distance
# 3. **Lightning Fast Performance**: Even with millions of documents, searches happen in milliseconds

# %% [markdown]
# ## 🔍 Testing Similarity
#
# Let's measure how similar our words are to each other. The computer will tell us which words are most related!

# %%
# Calculate similarity between 'dog' and all other words
dog_embedding = embeddings[0].reshape(1, -1)  # 'dog' is first word
other_embeddings = embeddings[1:]  # puppy, cat, car

# Calculate cosine similarity (higher = more similar)
similarities = cosine_similarity(dog_embedding, other_embeddings)[0]

print("🐕 How similar is 'dog' to other words?")
print()
for word, similarity in zip(words[1:], similarities):
    print(f"dog ↔ {word}: {similarity:.3f}")
    
print()
print("📊 Notice:")
print("• 'dog' and 'puppy' are most similar (both canines)")
print("• 'dog' and 'cat' have some similarity (both pets)")
print("• 'dog' and 'car' are least similar (totally different concepts)")

# %% [markdown]
# ## 🗺️ A Map of Meaning
#
# We can plot words as points in space. Words with similar meanings end up close together — words with different meanings end up far apart.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def plot_embedding_map(labels, embeddings, title='Words plotted by meaning — closer = more similar'):
    coords = PCA(n_components=2).fit_transform(embeddings)
    x_pad = (coords[:, 0].max() - coords[:, 0].min()) * 0.5
    y_pad = (coords[:, 1].max() - coords[:, 1].min()) * 0.5

    palette = ['#e74c3c', '#e67e22', '#3498db', '#2ecc71', '#9b59b6', '#1abc9c', '#e91e63', '#ff9800']
    colors = palette[:len(labels)]

    fig, ax = plt.subplots(figsize=(7, 6))
    fig.patch.set_facecolor('#f9f7ff')
    ax.set_facecolor('#f9f7ff')

    for label, (x, y), color in zip(labels, coords, colors):
        ax.scatter(x, y, color=color, s=500, zorder=3, alpha=0.85, edgecolors='white', linewidths=2)
        ax.annotate(label, (x, y), textcoords='offset points', xytext=(12, 4),
                    fontsize=12, fontweight='bold', color=color)

    ax.set_xlim(coords[:, 0].min() - x_pad, coords[:, 0].max() + x_pad)
    ax.set_ylim(coords[:, 1].min() - y_pad, coords[:, 1].max() + y_pad)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(title, fontsize=13, pad=12)
    for spine in ax.spines.values():
        spine.set_visible(False)
    ax.grid(True, alpha=0.15, linestyle='--')
    plt.tight_layout()
    plt.show()

plot_embedding_map(words, embeddings)

# %% [markdown]
# ## 🎮 Try It Yourself!
#
# Want to test similarity between your own words or phrases? Run the cell below and experiment!

# %%
# Try your own words or phrases!
# Change these to anything you want to compare
test_words = [
    "machine learning",
    "artificial intelligence", 
    "deep learning",
    "cooking recipes"
]

# Create embeddings
test_embeddings = model.encode(test_words)

# Compare first phrase with all others
base_embedding = test_embeddings[0].reshape(1, -1)
other_test_embeddings = test_embeddings[1:]
test_similarities = cosine_similarity(base_embedding, other_test_embeddings)[0]

print(f"🧪 How similar is '{test_words[0]}' to other phrases?")
print()
for phrase, similarity in zip(test_words[1:], test_similarities):
    print(f"'{test_words[0]}' ↔ '{phrase}': {similarity:.3f}")

print()
print("💡 Try changing the test_words list above and rerun to experiment!")

plot_embedding_map(test_words, test_embeddings)

# %% [markdown]
# ## 🚀 Congratulations!
#
# You now know how to use embeddings, unlocking one of the most flexible ways to search for text.
# Now go back to the instructions to learn where we can store and retreive these embeddings and their accompanying text snippets.
